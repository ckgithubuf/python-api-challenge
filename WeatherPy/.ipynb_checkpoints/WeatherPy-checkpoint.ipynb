# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# url = "https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}"
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'metric'
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat'] #x
        city_lng = city_weather['coord']['lon'] #y
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | howrah
# Processing Record 2 of Set 1 | afaahiti
# Processing Record 3 of Set 1 | papatowai
# Processing Record 4 of Set 1 | dryden
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | sisimiut
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | vila franca do campo
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | northam
# Processing Record 12 of Set 1 | manaure
# Processing Record 13 of Set 1 | sur
# Processing Record 14 of Set 1 | veraval
# Processing Record 15 of Set 1 | hawaiian paradise park
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | sola
# Processing Record 18 of Set 1 | kenai
# Processing Record 19 of Set 1 | enewetak
# Processing Record 20 of Set 1 | slave lake
# Processing Record 21 of Set 1 | dolores
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                       howrah  22.5892   88.3103     17.00        67
# 1                     afaahiti -17.7500 -149.2833     27.93        94
# 2                    papatowai -46.5619  169.4708     15.83        57
# 3                       dryden  49.7833  -92.7503     -6.84        73
# 4  edinburgh of the seven seas -37.0676  -12.3116     17.38        74
#
#    Cloudiness  Wind Speed Country        Date
# 0          40        0.00      IN  1707691921
# 1          71       12.37      PF  1707691921
# 2         100        5.15      NZ  1707691921
# 3         100        2.57      CA  1707691922
# 4          14        8.47      SH  1707691922

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                             howrah  22.5892   88.3103     17.00        67
# 1                           afaahiti -17.7500 -149.2833     27.93        94
# 2                          papatowai -46.5619  169.4708     15.83        57
# 3                             dryden  49.7833  -92.7503     -6.84        73
# 4        edinburgh of the seven seas -37.0676  -12.3116     17.38        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        0.00      IN  1707691921
# 1                71       12.37      PF  1707691921
# 2               100        5.15      NZ  1707691921
# 3               100        2.57      CA  1707691922
# 4                14        8.47      SH  1707691922

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat = city_data_df['Lat']
temp = city_data_df['Max Temp']
plt.scatter(lat, temp, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title("Latitude vs Max temperature")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat = city_data_df['Lat']
humidity = city_data_df['Humidity']
plt.scatter(lat, humidity, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']
plt.scatter(lat, cloudiness, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Latitude vs Cloudiness")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat = city_data_df['Lat']
windspeed = city_data_df['Wind Speed']
plt.scatter(lat, windspeed, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title("City Latitude vs Wind Speed")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y, xlabel, ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    print(f"The r-value is : {rvalue}")
    regress_values = x * slope + intercept    
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x, y)
    plt.plot(x, regress_values,"r-")
    plt.annotate(line_eq, (0,0), fontsize=15, color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                      howrah  22.5892  88.3103     17.00        67
# 3                      dryden  49.7833 -92.7503     -6.84        73
# 6                    sisimiut  66.9395 -53.6735    -22.88        88
# 8        vila franca do campo  37.7167 -25.4333     18.27        99
# 10                    northam  51.0333  -4.2167      7.03        91
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        0.00      IN  1707691921
# 3               100        2.57      CA  1707691922
# 6                58        3.50      GL  1707691923
# 8                60        7.26      PT  1707691924
# 10               63        7.61      GB  1707691924

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                           afaahiti -17.7500 -149.2833     27.93        94
# 2                          papatowai -46.5619  169.4708     15.83        57
# 4        edinburgh of the seven seas -37.0676  -12.3116     17.38        74
# 5                          grytviken -54.2811  -36.5092      4.13        84
# 7                          adamstown -25.0660 -130.1015     25.04        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                71       12.37      PF  1707691921
# 2               100        5.15      NZ  1707691921
# 4                14        8.47      SH  1707691922
# 5                16        5.09      GS  1707691923
# 7                38        8.44      PN  1707691923

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lat = northern_hemi_df['Lat']
temp = northern_hemi_df['Max Temp']
linear_regression(lat, temp, 'Latitude', 'Max Temp')
# Out:
# The r-value is : -0.8735009346750936

# %%
# Linear regression on Southern Hemisphere
lat = southern_hemi_df['Lat']
temp = southern_hemi_df['Max Temp']
linear_regression(lat, temp, 'Latitude', 'Max Temp')
# Out:
# The r-value is : 0.5706362039087258

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, as latitude is decreasing the temperature is raising, In southern hemisphere, as the temperate is increasing temperature is raising. This means that at equador temperature is usually higher

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat = northern_hemi_df['Lat']
humidity = northern_hemi_df['Humidity']
linear_regression(lat, humidity, 'Latitude', 'Humidity')
# Out:
# The r-value is : 0.3966546817542445

# %%
# Southern Hemisphere
lat = southern_hemi_df['Lat']
humidity = southern_hemi_df['Humidity']
linear_regression(lat, humidity, 'Latitude', 'Humidity')
# Out:
# The r-value is : 0.45355290876648247

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, as latitude is increasing the humidity is raising, In southern hemisphere, as the temperate is increasing humidity is raising. The correlation is weak though.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat = northern_hemi_df['Lat']
cloudiness = northern_hemi_df['Cloudiness']
linear_regression(lat, cloudiness, 'Latitude', 'Cloudiness')
# Out:
# The r-value is : 0.3284191255703846

# %%
# Southern Hemisphere
lat = southern_hemi_df['Lat']
cloudiness = southern_hemi_df['Cloudiness']
linear_regression(lat, cloudiness, 'Latitude', 'Humidity')
# Out:
# The r-value is : 0.356186312762075

# %% [markdown]
# **Discussion about the linear relationship:**  In northern hemisphere & south, there seems to be no strong correlation between latitude and humidity

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat = northern_hemi_df['Lat']
windspeed = northern_hemi_df['Wind Speed']
linear_regression(lat, windspeed, 'Latitude', 'Wind Speed')
# Out:
# The r-value is : -0.131709328188039

# %%
# Southern Hemisphere
lat = southern_hemi_df['Lat']
windspeed = southern_hemi_df['Wind Speed']
linear_regression(lat, windspeed, 'Latitude', 'Wind Speed')
# Out:
# The r-value is : -0.24053971160404217

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere & south, there seems to be no strong correlation between latitude and windspeed
